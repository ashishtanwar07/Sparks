# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishtanwar07/Sparks/blob/main/GRIP_Task_5_Exploratory_Data_Analysis_IPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![By Ashish Tanwer.png](data:image/png;base64,...)

# %% [markdown]
# ![task5.png](data:image/png;base64,...)

# %% [markdown]
# Task-5
#
# ● Perform ‘Exploratory Data Analysis’ on dataset ‘Indian Premier League’
#
# ● As a sports analysts, find out the most successful teams, players and factors contributing win or loss of a team.
#
# ● Suggest teams or players a company should endorse for its products.
#
# ● You can choose any of the tool of your choice (Python/R/Tableau/PowerBI/Excel/SAP/SAS) ● Dataset: https://bit.ly/34SRn3b
#
# ● Advanced Level - Create storyboards. Screen-record along with your audio explaining the charts and interpretations. Use annotations, animation and images.
#
# ● Task submission: 1. Create the dashboards and/or storyboard and record it 2. Upload the recording on Youtube, share the link on LinkedIn 3. Submit LinkedIn post link in Task Submission Form when shared 4. Please read FAQs on how to submit the tasks.**

# %%
![picture](https://drive.google.com/file/d/1-FWhgp97K1NNPCUZD4DBfBytunf5MOWh/view?usp=sharing)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/file/d/1-FWhgp97K1NNPCUZD4DBfBytunf5MOWh/view?usp=sharing'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/file/d/1-FWhgp97K1NNPCUZD4DBfBytunf5MOWh/view?usp=sharing)'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#file import from device drive
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-460e90dd-d56d-40b3-9614-9ac69f01dd25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-460e90dd-d56d-40b3-9614-9ac69f01dd25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving matches.csv to matches.csv

# %%
df = pd.read_csv('matches.csv') 
print(df)
# Out:
#         id  season  ...         umpire2                  umpire3
# 0        1    2017  ...        NJ Llong                      NaN
# 1        2    2017  ...          S Ravi                      NaN
# 2        3    2017  ...       CK Nandan                      NaN
# 3        4    2017  ...   C Shamshuddin                      NaN
# 4        5    2017  ...             NaN                      NaN
# ..     ...     ...  ...             ...                      ...
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
# 755  11415    2019  ...       Ian Gould              Nigel Llong
#
# [756 rows x 18 columns]

# %%
df.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
df.shape
# Out:
# (756, 18)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %% [markdown]
# Let's check unique values for every feature we've got here.

# %%
df.nunique()
# Out:
# id                 756
# season              12
# city                32
# date               546
# team1               15
# team2               15
# toss_winner         15
# toss_decision        2
# result               3
# dl_applied           2
# winner              15
# win_by_runs         89
# win_by_wickets      11
# player_of_match    226
# venue               41
# umpire1             61
# umpire2             65
# umpire3             25
# dtype: int64

# %%
x=input("\nEnter a coloumn keys to check unique values\n")
print(df[x].unique())
# Out:
# Enter a coloumn keys to check unique values
# venue
# ['Rajiv Gandhi International Stadium, Uppal'
#  'Maharashtra Cricket Association Stadium'
#  'Saurashtra Cricket Association Stadium' 'Holkar Cricket Stadium'
#  'M Chinnaswamy Stadium' 'Wankhede Stadium' 'Eden Gardens'
#  'Feroz Shah Kotla' 'Punjab Cricket Association IS Bindra Stadium, Mohali'
#  'Green Park' 'Punjab Cricket Association Stadium, Mohali'
#  'Sawai Mansingh Stadium' 'MA Chidambaram Stadium, Chepauk'
#  'Dr DY Patil Sports Academy' 'Newlands' "St George's Park" 'Kingsmead'
#  'SuperSport Park' 'Buffalo Park' 'New Wanderers Stadium'
#  'De Beers Diamond Oval' 'OUTsurance Oval' 'Brabourne Stadium'
#  'Sardar Patel Stadium, Motera' 'Barabati Stadium'
#  'Vidarbha Cricket Association Stadium, Jamtha'
#  'Himachal Pradesh Cricket Association Stadium' 'Nehru Stadium'
#  'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium'
#  'Subrata Roy Sahara Stadium'
#  'Shaheed Veer Narayan Singh International Stadium'
# ...

# %%
print("\nlength")
len(df[x].unique())
# Out:
# length
# 41

# %%
#check separete coloumn and count values
print("coloumn keys")
print(df.columns)
y=input("\nEnter a coloumn keys to check unique values\n")
df[y].value_counts()
# Out:
# coloumn keys
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')
#
# Enter a coloumn keys to check unique values
# season
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
df[['season']].value_counts()
# Out:
# season
# 2013      76
# 2012      74
# 2011      73
# 2019      60
# 2018      60
# 2016      60
# 2014      60
# 2010      60
# 2017      59
# 2015      59
# 2008      58
# 2009      57
# dtype: int64

# %% [markdown]
# Let's have a look if we got any null values in any of our features.

# %%
df.isnull()
# Out:
#         id  season   city   date  ...  venue  umpire1  umpire2  umpire3
# 0    False   False  False  False  ...  False    False    False     True
# 1    False   False  False  False  ...  False    False    False     True
# 2    False   False  False  False  ...  False    False    False     True
# 3    False   False  False  False  ...  False    False    False     True
# 4    False   False  False  False  ...  False     True     True     True
# ..     ...     ...    ...    ...  ...    ...      ...      ...      ...
# 751  False   False  False  False  ...  False    False    False    False
# 752  False   False  False  False  ...  False    False    False    False
# 753  False   False  False  False  ...  False     True     True     True
# 754  False   False  False  False  ...  False    False    False    False
# 755  False   False  False  False  ...  False    False    False    False
#
# [756 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())

# %%
#Let`s have a look at numeric feature of the data. and we will look at their stats.

df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
# Let's check what is the maximum winning score diff

df['win_by_runs'].max()
# Out:
# 146

# %%
# Let's grab that match where winning score is highest.
df.iloc[df['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
# Let's check what is the average winning score diff
df['win_by_runs'].mean()
# Out:
# 13.283068783068783

# %%
#Let's look over the list of highest winning score diff
max_win_team1=df.groupby('winner')['win_by_runs'].max().sort_values(ascending = False)
max_win_team1
# Out:
# winner
# Mumbai Indians                 146
# Royal Challengers Bangalore    144
# Kolkata Knight Riders          140
# Sunrisers Hyderabad            118
# Kings XI Punjab                111
# Rajasthan Royals               105
# Delhi Daredevils                97
# Chennai Super Kings             97
# Deccan Chargers                 82
# Rising Pune Supergiant          61
# Delhi Capitals                  39
# Pune Warriors                   38
# Rising Pune Supergiants         34
# Kochi Tuskers Kerala            17
# Gujarat Lions                    1
# Name: win_by_runs, dtype: int64

# %%
# maximum win by run visualization
max_win_team1.plot(kind = 'bar',color='c',figsize=(10,5),title="Win By Maximum Number Of Runs\n")

# %%
#win by maximum number of wickets
max_win_by_wickets=df.groupby('winner')['win_by_wickets'].max().sort_values(ascending = False)
max_win_by_wickets
# Out:
# winner
# Sunrisers Hyderabad            10
# Royal Challengers Bangalore    10
# Rajasthan Royals               10
# Mumbai Indians                 10
# Kolkata Knight Riders          10
# Kings XI Punjab                10
# Delhi Daredevils               10
# Deccan Chargers                10
# Chennai Super Kings            10
# Rising Pune Supergiants         9
# Rising Pune Supergiant          9
# Kochi Tuskers Kerala            8
# Pune Warriors                   7
# Gujarat Lions                   7
# Delhi Capitals                  7
# Name: win_by_wickets, dtype: int64

# %%
max_win_by_wickets.plot(kind = 'bar',color='c',figsize=(10,5),title="Win By Maximum Number Of Runs\n")

# %%
# Let's check what is the Minimum winning score diff
df['win_by_runs'].min()
# Out:
# 0

# %%
# Let's grab those matches where winning difference is 0
df[df['win_by_runs']==0]
# Out:
#         id  season  ...         umpire2                  umpire3
# 1        2    2017  ...          S Ravi                      NaN
# 2        3    2017  ...       CK Nandan                      NaN
# 3        4    2017  ...   C Shamshuddin                      NaN
# 5        6    2017  ...        NJ Llong                      NaN
# 6        7    2017  ...       CK Nandan                      NaN
# ..     ...     ...  ...             ...                      ...
# 750  11346    2019  ...   C Shamshuddin           Bruce Oxenford
# 751  11347    2019  ...        O Nandan                   S Ravi
# 752  11412    2019  ...     Nitin Menon                Ian Gould
# 753  11413    2019  ...             NaN                      NaN
# 754  11414    2019  ...  Bruce Oxenford  Chettithody Shamshuddin
#
# [419 rows x 18 columns]

# %%
#Let's look in which city we got the maximum matches where winning score is 0
a=df[df['win_by_runs']==0]

# %%
len(a)
# Out:
# 419

# %%
plt.figure(figsize=(20,6))
df['city'].value_counts().plot(kind='bar',color='c')

# %%
plt.figure(figsize=(15,5))
df['toss_winner'].value_counts().plot(kind='bar',color='c')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab3e33fb63ca> in <module>()
# ----> 1 plt.figure(figsize=(15,5))
#       2 df['toss_winner'].value_counts().plot(kind='bar',color='c')
#
# NameError: name 'plt' is not defined

# %%
df['toss_decision'].value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
sns.displot(df, x='toss_decision',color='darkseagreen')

# %%
#man of the match player name
df["player_of_match"].unique()
# Out:
# array(['Yuvraj Singh', 'SPD Smith', 'CA Lynn', 'GJ Maxwell', 'KM Jadhav',
#        'Rashid Khan', 'N Rana', 'AR Patel', 'SV Samson', 'JJ Bumrah',
#        'SP Narine', 'KA Pollard', 'AJ Tye', 'RV Uthappa', 'CJ Anderson',
#        'BA Stokes', 'NM Coulter-Nile', 'B Kumar', 'CH Gayle',
#        'KS Williamson', 'JC Buttler', 'SK Raina', 'MJ McClenaghan',
#        'MS Dhoni', 'HM Amla', 'G Gambhir', 'LH Ferguson', 'KH Pandya',
#        'Sandeep Sharma', 'DA Warner', 'RG Sharma', 'Mohammed Shami',
#        'RA Tripathi', 'RR Pant', 'JD Unadkat', 'LMP Simmons', 'DR Smith',
#        'S Dhawan', 'MM Sharma', 'SS Iyer', 'WP Saha', 'KK Nair',
#        'Mohammed Siraj', 'AT Rayudu', 'HV Patel', 'Washington Sundar',
#        'KV Sharma', 'BB McCullum', 'MEK Hussey', 'MF Maharoof',
#        'MV Boucher', 'DJ Hussey', 'SR Watson', 'V Sehwag', 'ML Hayden',
#        'YK Pathan', 'KC Sangakkara', 'JDP Oram', 'AC Gilchrist',
#        'SM Katich', 'ST Jayasuriya', 'GD McGrath', 'SE Marsh',
# ...

# %%
man_of_match=df['player_of_match'].value_counts()
print(man_of_match)
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# DA Warner         17
# MS Dhoni          17
#                   ..
# J Archer           1
# SA Asnodkar        1
# CR Brathwaite      1
# BCJ Cutting        1
# DJG Sammy          1
# Name: player_of_match, Length: 226, dtype: int64

# %%
#top 10 succesfull players
man_of_match[:10].plot(kind = 'bar',color="sandybrown",figsize=(10,5),title="Top 10 Man Of The Match\n")

# %%
df['dl_applied'].value_counts()
# Out:
# 0    737
# 1     19
# Name: dl_applied, dtype: int64

# %%
#according to tosswinner player performance  analysis
toss =df.groupby(['team1','team2','winner','toss_winner','season','win_by_runs','win_by_wickets'])['player_of_match','toss_decision'].max().sort_values(by = 'player_of_match',ascending = False)
toss
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                                                                                                   player_of_match toss_decision
# team1                       team2                       winner                      toss_winner                 season win_by_runs win_by_wickets
# Chennai Super Kings         Delhi Daredevils            Delhi Daredevils            Chennai Super Kings         2015   0           6                       Z Khan           bat
# Sunrisers Hyderabad         Royal Challengers Bangalore Sunrisers Hyderabad         Royal Challengers Bangalore 2017   35          0                 Yuvraj Singh         field
# ...

# %%
#print according to toss_winning player performance
player_name= input("enter the player name")
individual_player=toss2[toss['player_of_match'] == player_name]
individual_player
# Out:
# enter the player nameYuvraj Singh
#                                                                                                                                                   player_of_match toss_decision
# team1                       team2                       winner                      toss_winner                 season win_by_runs win_by_wickets
# Sunrisers Hyderabad         Royal Challengers Bangalore Sunrisers Hyderabad         Royal Challengers Bangalore 2017   35          0                 Yuvraj Singh         field
# Pune Warriors               Delhi Daredevils            Delhi Daredevils            Delhi Daredevils            2011   0           3                 Yuvraj Singh         field
# Royal Challengers Bangalore Delhi Daredevils            Royal Challengers Bangalore Delhi Daredevils            2014   16          0                 Yuvraj Singh         field
# ...

# %%
#individual season
print("SEASON(2008-2019)")
ses=int(input("Enter a season"))
individual_season=df.loc[df['season'] == ses]
print(individual_season.head())
# Out:
# SEASON(2008-2019)
# Enter a season2008
#     id  season        city  ...         umpire2 umpire3 man_of_match
# 59  60    2008   Bangalore  ...     RE Koertzen     NaN          NaN
# 60  61    2008  Chandigarh  ...      SL Shastri     NaN          NaN
# 61  62    2008       Delhi  ...  GA Pratapkumar     NaN          NaN
# 62  63    2008      Mumbai  ...       DJ Harper     NaN          NaN
# 63  64    2008     Kolkata  ...     K Hariharan     NaN          NaN
#
# [5 rows x 19 columns]

# %%
#Let's have a look at most successfull player in particular season

x=individual_season[['player_of_match','season']].value_counts()
print(x)
len(x)
# Out:
# player_of_match   season
# SE Marsh          2008      5
# YK Pathan         2008      4
# SR Watson         2008      4
# SM Pollock        2008      2
# M Ntini           2008      2
# V Sehwag          2008      2
# MS Dhoni          2008      2
# SC Ganguly        2008      2
# AC Gilchrist      2008      2
# ST Jayasuriya     2008      2
# Sohail Tanvir     2008      2
# BB McCullum       2008      1
# CRD Fernando      2008      1
# KC Sangakkara     2008      1
# DJ Bravo          2008      1
# DJ Hussey         2008      1
# DPMD Jayawardene  2008      1
# GC Smith          2008      1
# GD McGrath        2008      1
# A Nehra           2008      1
# IK Pathan         2008      1
# JA Morkel         2008      1
# A Mishra          2008      1
# JDP Oram          2008      1
# MF Maharoof       2008      1
# KD Karthik        2008      1
# L Balaji          2008      1
# MEK Hussey        2008      1
# ML Hayden         2008      1
# MV Boucher        2008      1
# ...

# %%
#Player OF The Match(2018) 
x.plot(kind = 'bar',color='steelblue',figsize=(20,5),title="Player OF The Match(2015)\n")

# %%
#Let's have a look which fature of this dataset are most correlated.
corr=df.corr()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr,annot=True)

# %% [markdown]
# **Thankyou Have a nice day**
